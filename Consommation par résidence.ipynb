# %%
# !pip install pandas
# !pip install geopandas

# %%
import pandas as pd
import requests
import geopandas as gpd

# %%
def get_dataset_from_url(api_url):
    '''Imports a database from an API url.
    Args:
        api_url (string) : url of the wanted API
    Returns:
        pandas.DataFrame : dataframe
    '''
    req=requests.get(api_url)
    wb=req.json()
    df = pd.json_normalize(wb["results"])
    #dataset = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude), crs = 4326)

    return df
# Out:
#   annee  code_iris                       nom_iris  numero_de_voie  \
# 0  2019  593610000  Lourches (commune non irisée)               9
# 1  2019  652860103              Ophite-Chantecler               7
# 2  2019  652860103              Ophite-Chantecler               5
# 3  2019  652860103              Ophite-Chantecler              37
# 4  2019  652860103              Ophite-Chantecler               4
# 5  2019  652860102                    Centre-Soum              10
# 6  2019  652860108    Secteur Hôtelier-Sanctuaire              12
# 7  2019  652860102                    Centre-Soum              74
# 8  2019  652860103              Ophite-Chantecler               1
# 9  2019  652860104                    Centre-Gare              11
#
#   indice_de_repetition type_de_voie   libelle_de_voie code_commune  \
# 0                 None          RUE       PATRICK ROY        59361
# 1                 None          RUE    ANSELME LACADE        65286
# 2                 None        PLACE       CAPDEVIELLE        65286
# 3                 None          RUE       DE BAGNERES        65286
# 4                 None          RUE    DE L AUBERTRON        65286
# 5                 None          RUE    DE LA FONTAINE        65286
# 6                 None    BOULEVARD      DE LA GROTTE        65286
# 7                 None          RUE      DE LA GROTTE        65286
# 8                 None        PLACE  DE LA REPUBLIQUE        65286
# 9                 None          RUE       DES CHALETS        65286
#
#   nom_commune segment_de_client  nombre_de_logements  \
# 0    Lourches       RESIDENTIEL                   20
# 1     Lourdes       RESIDENTIEL                   16
# 2     Lourdes       RESIDENTIEL                   24
# 3     Lourdes       RESIDENTIEL                   12
# 4     Lourdes       RESIDENTIEL                   13
# 5     Lourdes       RESIDENTIEL                   10
# 6     Lourdes       RESIDENTIEL                   12
# 7     Lourdes       RESIDENTIEL                   17
# 8     Lourdes       RESIDENTIEL                   41
# 9     Lourdes       RESIDENTIEL                   18
#
#    consommation_annuelle_totale_de_l_adresse_mwh  \
# 0                                         20.923
# 1                                         36.520
# 2                                         86.653
# 3                                         30.983
# 4                                         45.462
# 5                                         33.545
# 6                                         40.007
# 7                                         29.130
# 8                                        169.650
# 9                                         57.633
#
#    consommation_annuelle_moyenne_par_site_de_l_adresse_mwh  \
# 0                                              1.046
# 1                                              2.282
# 2                                              3.611
# 3                                              2.582
# 4                                              3.497
# 5                                              3.355
# 6                                              3.334
# 7                                              1.714
# 8                                              4.138
# 9                                              3.202
#
#    consommation_annuelle_moyenne_de_la_commune_mwh                    adresse  \
# 0                                            3.988          9 RUE PATRICK ROY
# 1                                            3.449       7 RUE ANSELME LACADE
# 2                                            3.449        5 PLACE CAPDEVIELLE
# 3                                            3.449         37 RUE DE BAGNERES
# 4                                            3.449       4 RUE DE L AUBERTRON
# 5                                            3.449      10 RUE DE LA FONTAINE
# 6                                            3.449  12 BOULEVARD DE LA GROTTE
# 7                                            3.449        74 RUE DE LA GROTTE
# 8                                            3.449   1 PLACE DE LA REPUBLIQUE
# 9                                            3.449         11 RUE DES CHALETS
#
#    tri_des_adresses  code_epci code_departement code_region
# 0            160012  200042190               59          32
# 1            160014  200069300               65          76
# 2            160022  200069300               65          76
# 3            160027  200069300               65          76
# 4            160032  200069300               65          76
# 5            160033  200069300               65          76
# 6            160034  200069300               65          76
# 7            160035  200069300               65          76
# 8            160038  200069300               65          76
# 9            160054  200069300               65          76

# %% [markdown]
# ## Téléchargement des données de consommation d'électricité annuelle par adresse

# %%
consumption_api_root="https://enedis.opendatasoft.com/api/explore/v2.1/catalog/datasets/consommation-annuelle-residentielle-par-adresse/records"

def get_consumption(api_root, year):
    consumption_api_url=f"{api_root}?refine=annee"+"%3A"+f"{year}"
    return get_dataset_from_url(consumption_api_url)

consumption_2018 = get_consumption(consumption_api_root, "2018")
consumption_2019 = get_consumption(consumption_api_root, "2019")
consumption_2020 = get_consumption(consumption_api_root, "2020")
consumption_2021 = get_consumption(consumption_api_root, "2021")
# Out:
#   annee  code_iris                   nom_iris  numero_de_voie  \
# 0  2018  593920202                Pont Allant              45
# 1  2018  492440101                  Pommeraye              14
# 2  2018  49244xxxx  Fictif - Mauges-sur-Loire              35
# 3  2018  341540105                     Carnon             135
# 4  2018  341540102             Quartier ouest              54
#
#   indice_de_repetition type_de_voie libelle_de_voie code_commune  \
# 0                 None          RUE    LEON BATHIAT        59392
# 1                 None          RUE    MARIE MOREAU        49244
# 2                 None          RUE       NATIONALE        49244
# 3                 None          RUE  DE LA GARDIOLE        34154
# 4                 None          RUE   DE LA MESANGE        34154
#
#         nom_commune segment_de_client  nombre_de_logements  \
# 0          MAUBEUGE       RESIDENTIEL                   61
# 1  MAUGES-SUR-LOIRE       RESIDENTIEL                   21
# 2  MAUGES-SUR-LOIRE       RESIDENTIEL                   23
# 3           MAUGUIO       RESIDENTIEL                   27
# 4           MAUGUIO       RESIDENTIEL                   10
#
#    consommation_annuelle_totale_de_l_adresse_mwh  \
# 0                                        154.865
# 1                                        107.920
# 2                                        125.959
# 3                                         62.629
# 4                                         64.527
#
#    consommation_annuelle_moyenne_par_site_de_l_adresse_mwh  \
# 0                                              2.539
# 1                                              5.139
# 2                                              5.476
# 3                                              2.320
# 4                                              6.453
#
#    consommation_annuelle_moyenne_de_la_commune_mwh                 adresse  \
# 0                                            3.246     45 RUE LEON BATHIAT
# 1                                            6.274     14 RUE MARIE MOREAU
# 2                                            6.274        35 RUE NATIONALE
# 3                                            4.802  135 RUE DE LA GARDIOLE
# 4                                            4.802    54 RUE DE LA MESANGE
#
#    tri_des_adresses  code_epci code_departement code_region
# 0            580004  200043396               59          32
# 1            580013  200060010               49          52
# 2            580014  200060010               49          52
# 3            580018  243400470               34          76
# 4            580024  243400470               34          76
